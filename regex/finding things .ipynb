# %%
import re

# %%
para=""""
2022-02-24 17:16:35,658 WARN  [RSProcedureDispatcher-pool-31] procedure.RSProcedureDispatcher: request to londaristacvp04.corp.bloomberg.com,16201,1645720819025 failed due to org.apache.hadoop.hbase.ipc.CallTimeoutException: Call to londaristacvp04.corp.bloomberg.com/10.142.165.224:16201 failed on local exception:wwraosami1122@gmail.com org.apache.hadoop.hbase.ipc.CallTimeoutException: Call[id=31,methodName=ExecuteProcedures], waitTime=60009, rpcTimeout=60000, try=31, retrying...(123)-234-567
2022-02-24 17:17:33,961 WARN  [master/londaristacvp03:16000:becomeActiveMaster] master.HMasterabc12@gmail.com hbase:meta,,1.1588230740 is NOT online; state={1588230740 state=OPENING, ts=1645720826620, server=londaristacvp04.corp.bloomberg.com,16201,1645720819025}; ServerCrashProcedures=true. Master startup cannot progress, in holding-pattern until region onlined.
2022-02-24 17:17:45,668 WARN  [RSProcedureDispatcher-pool-32] procedure.RSProcedureDispatcher: request to londaristacvp04.corp.bloomberg.com,(16201),16457208190251 failed due to org.apache.hadoop.hbase.ipc.CallTimeoutException: Call to londaristacvp04.corp.bloomberg.com/10.142.165.224:16201 failed on local exception: org.apache.hadoop.hbase.ipc.CallTimeoutException: Call[id=32,methodName=ExecuteProcedures], waitTime=60008, rpcTimeout=60000, try=32, retrying...
2022-02-24 17:18:33,962 WARN  [master/londaristacvp03:16000:becomeActiveMaster] master.HMaster: hbase:meta,,1.1588230740 is NOT online; state={1588230740 state=OPENING, ts=1645720826620, server=londaristacvp04.corp.bloomberg.com,16201,1645720819025}; ServerCrashProcedures=true. Master startup cannot progress, in holding-pattern until region onlined.
2022-02-24 17:18:55,678 WARN  [RSProcedureDispatcher-pool-33] procedure.RSProcedureDispatcher: request to londaristacvp04.corp.bloomberg.com,16201,1645720819025 failed due to org.apache.hadoop.hbase.ipc.CallTimeoutException: Call to londaristacvp04.corp.bloomberg.com/10.142.165.224:16201 failed on local exception: org.apache.hadoop.hbase.ipc.CallTimeoutException: Call[id=33,methodName=ExecuteProcedures], waitTime=60008, rpcTimeout=60000, try=33, retrying...
2022-02-24 17:19:33,962 WARN  [master/londaristacvp03:16000:becomeActiveMaster] master.HMaster: hbase:meta,,1.1588230740 is NOT online; state={1588230740 state=OPENING, ts=1645720826620,abc@gmail.com
server=londaristacvp04.corp.bloomberg.com,16201,1645720819025}; ServerCrashProcedures=true. Master startup cannot progress, in holding-pattern until region onlined.
2022-02-24 17:20:05,688 WARN  [RSProcedureDispatcher-pool-34] procedure.RSProcedureDispatcher: request to londaristacvp04.corp.bloomberg.com,16201,1645720819025 failed due to org.apache.hadoop.hbase.ipc.CallTimeoutException: Call to londaristacvp04.corp.bloomberg.com/10.142.165.224:16201 failed on local exception:ABC@gmail.com org.apache.hadoop.hbase.ipc.CallTimeoutException!23@gmail.com: Call[id=34,methodName=ExecuteProcedures], waitTime=60008, rpcTimeout=60000, try=34, retrying...abcA@gmail.com
"""

# %%
para
# Out:
# '"\n2022-02-24 17:16:35,658 WARN  [RSProcedureDispatcher-pool-31] procedure.RSProcedureDispatcher: request to londaristacvp04.corp.bloomberg.com,16201,1645720819025 failed due to org.apache.hadoop.hbase.ipc.CallTimeoutException: Call to londaristacvp04.corp.bloomberg.com/10.142.165.224:16201 failed on local exception:wwraosami1122@gmail.com org.apache.hadoop.hbase.ipc.CallTimeoutException: Call[id=31,methodName=ExecuteProcedures], waitTime=60009, rpcTimeout=60000, try=31, retrying...(123)-234-567\n2022-02-24 17:17:33,961 WARN  [master/londaristacvp03:16000:becomeActiveMaster] master.HMasterabc12@gmail.com hbase:meta,,1.1588230740 is NOT online; state={1588230740 state=OPENING, ts=1645720826620, server=londaristacvp04.corp.bloomberg.com,16201,1645720819025}; ServerCrashProcedures=true. Master startup cannot progress, in holding-pattern until region onlined.\n2022-02-24 17:17:45,668 WARN  [RSProcedureDispatcher-pool-32] procedure.RSProcedureDispatcher: request to londaristacvp04.corp.b
# ...

# %%
pattern=r"\d{4}"




re.findall(pattern,para)
# Out:
# ['2022',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '1620',
#  '1122',
#  '6000',
#  '6000',
#  '2022',
#  '1600',
#  '1588',
#  '2307',
#  '1588',
#  '2307',
#  '1645',
#  '7208',
#  '2662',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '2022',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '1620',
#  '6000',
#  '6000',
#  '2022',
#  '1600',
#  '1588',
#  '2307',
#  '1588',
#  '2307',
#  '1645',
#  '7208',
#  '2662',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '2022',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '1620',
#  '6000',
#  '6000',
#  '2022',
#  '1600',
#  '1588',
#  '2307',
#  '1588',
#  '2307',
#  '1645',
#  '7208',
#  '2662',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '2022',
#  '1620',
#  '1645',
#  '7208',
#  '1902',
#  '1620',
#  '6000',
#  '6000']

# %%
pattern2=r"\(\d{3}\)"
re.findall(pattern2,para)
# Out:
# ['(123)']

# %%
pattern3=r"\(\d{3}\)-\d{3}-\d{3}"
re.findall(pattern3,para)
# Out:
# ['(123)-234-567']

# %%
pattern4=r"[^a-z]"
re.findall(pattern4,para)
# Out:
# ['"',
#  '\n',
#  '2',
#  '0',
#  '2',
#  '2',
#  '-',
#  '0',
#  '2',
#  '-',
#  '2',
#  '4',
#  ' ',
#  '1',
#  '7',
#  ':',
#  '1',
#  '6',
#  ':',
#  '3',
#  '5',
#  ',',
#  '6',
#  '5',
#  '8',
#  ' ',
#  'W',
#  'A',
#  'R',
#  'N',
#  ' ',
#  ' ',
#  '[',
#  'R',
#  'S',
#  'P',
#  'D',
#  '-',
#  '-',
#  '3',
#  '1',
#  ']',
#  ' ',
#  '.',
#  'R',
#  'S',
#  'P',
#  'D',
#  ':',
#  ' ',
#  ' ',
#  ' ',
#  '0',
#  '4',
#  '.',
#  '.',
#  '.',
#  ',',
#  '1',
#  '6',
#  '2',
#  '0',
#  '1',
#  ',',
#  '1',
#  '6',
#  '4',
#  '5',
#  '7',
#  '2',
#  '0',
#  '8',
#  '1',
#  '9',
#  '0',
#  '2',
#  '5',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'C',
#  'T',
#  'E',
#  ':',
#  ' ',
#  'C',
#  ' ',
#  ' ',
#  '0',
#  '4',
#  '.',
#  '.',
#  '.',
#  '/',
#  '1',
#  '0',
#  '.',
#  '1',
#  '4',
#  '2',
#  '.',
#  '1',
#  '6',
#  '5',
#  '.',
#  '2',
#  '2',
#  '4',
#  ':',
#  '1',
#  '6',
#  '2',
#  '0',
#  '1',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
# ...

# %%
pattern5=r"[a-z]"
re.findall(pattern5,para)
# Out:
# ['r',
#  'o',
#  'c',
#  'e',
#  'd',
#  'u',
#  'r',
#  'e',
#  'i',
#  's',
#  'p',
#  'a',
#  't',
#  'c',
#  'h',
#  'e',
#  'r',
#  'p',
#  'o',
#  'o',
#  'l',
#  'p',
#  'r',
#  'o',
#  'c',
#  'e',
#  'd',
#  'u',
#  'r',
#  'e',
#  'r',
#  'o',
#  'c',
#  'e',
#  'd',
#  'u',
#  'r',
#  'e',
#  'i',
#  's',
#  'p',
#  'a',
#  't',
#  'c',
#  'h',
#  'e',
#  'r',
#  'r',
#  'e',
#  'q',
#  'u',
#  'e',
#  's',
#  't',
#  't',
#  'o',
#  'l',
#  'o',
#  'n',
#  'd',
#  'a',
#  'r',
#  'i',
#  's',
#  't',
#  'a',
#  'c',
#  'v',
#  'p',
#  'c',
#  'o',
#  'r',
#  'p',
#  'b',
#  'l',
#  'o',
#  'o',
#  'm',
#  'b',
#  'e',
#  'r',
#  'g',
#  'c',
#  'o',
#  'm',
#  'f',
#  'a',
#  'i',
#  'l',
#  'e',
#  'd',
#  'd',
#  'u',
#  'e',
#  't',
#  'o',
#  'o',
#  'r',
#  'g',
#  'a',
#  'p',
#  'a',
#  'c',
#  'h',
#  'e',
#  'h',
#  'a',
#  'd',
#  'o',
#  'o',
#  'p',
#  'h',
#  'b',
#  'a',
#  's',
#  'e',
#  'i',
#  'p',
#  'c',
#  'a',
#  'l',
#  'l',
#  'i',
#  'm',
#  'e',
# ...

# %%
pattern6=r"[A-Z]"
re.findall(pattern6,para)
# Out:
# ['W',
#  'A',
#  'R',
#  'N',
#  'R',
#  'S',
#  'P',
#  'D',
#  'R',
#  'S',
#  'P',
#  'D',
#  'C',
#  'T',
#  'E',
#  'C',
#  'C',
#  'T',
#  'E',
#  'C',
#  'N',
#  'E',
#  'P',
#  'T',
#  'T',
#  'W',
#  'A',
#  'R',
#  'N',
#  'A',
#  'M',
#  'H',
#  'M',
#  'N',
#  'O',
#  'T',
#  'O',
#  'P',
#  'E',
#  'N',
#  'I',
#  'N',
#  'G',
#  'S',
#  'C',
#  'P',
#  'M',
#  'W',
#  'A',
#  'R',
#  'N',
#  'R',
#  'S',
#  'P',
#  'D',
#  'R',
#  'S',
#  'P',
#  'D',
#  'C',
#  'T',
#  'E',
#  'C',
#  'C',
#  'T',
#  'E',
#  'C',
#  'N',
#  'E',
#  'P',
#  'T',
#  'T',
#  'W',
#  'A',
#  'R',
#  'N',
#  'A',
#  'M',
#  'H',
#  'M',
#  'N',
#  'O',
#  'T',
#  'O',
#  'P',
#  'E',
#  'N',
#  'I',
#  'N',
#  'G',
#  'S',
#  'C',
#  'P',
#  'M',
#  'W',
#  'A',
#  'R',
#  'N',
#  'R',
#  'S',
#  'P',
#  'D',
#  'R',
#  'S',
#  'P',
#  'D',
#  'C',
#  'T',
#  'E',
#  'C',
#  'C',
#  'T',
#  'E',
#  'C',
#  'N',
#  'E',
#  'P',
#  'T',
#  'T',
#  'W',
#  'A',
#  'R',
#  'N',
#  'A',
#  'M',
# ...

# %%
pattern7=r"[a-zA-Z]*@"
re.findall(pattern7,para)
# Out:
# ['@g', '@g', 'abc@g', 'ABC@g', '@g', 'abcA@g']

# %%
pattern8=r"[a-z|A-Z|0-9]*@"
re.findall(pattern8,para)
# Out:
# ['wwraosami1122@', 'HMasterabc12@', 'abc@', 'ABC@', '23@', 'abcA@']

# %%
pattern9=r"[a-zA-Z0-9]*@[a-z0-9]*\.[a-z]*"       # * means the sequence  if  
re.findall(pattern9,para)
# Out:
# ['wwraosami1122@gmail.com',
#  'HMasterabc12@gmail.com',
#  'abc@gmail.com',
#  'ABC@gmail.com',
#  '23@gmail.com',
#  'abcA@gmail.com']

# %%
pattern10=r"[a-zA-Z]*@[a-z]*\.[a-z]" 
re.findall(pattern10,para)
# Out:
# ['@gmail.c',
#  '@gmail.c',
#  'abc@gmail.c',
#  'ABC@gmail.c',
#  '@gmail.c',
#  'abcA@gmail.c']

# %%
pattern11=r"[0-9\d{4}]*-[0-9]*\-[0-9]*"
re.findall(pattern11,para)
# Out:
# ['2022-02-24',
#  '-234-567',
#  '2022-02-24',
#  '2022-02-24',
#  '2022-02-24',
#  '2022-02-24',
#  '2022-02-24',
#  '2022-02-24']

# %%
paragraph1="""
this is my order no # 123456 and i felt a error 
"""
paragraph3="""
this is my order number 123456 and i felt a error 
"""
paragraph2="""
this is my orderno # 123456 and i felt a error 
"""

# %%
symbol=r"order[^\d]*[0-9]*"

# %%
re.findall(symbol,paragraph1),re.findall(symbol,paragraph2),re.findall(symbol,paragraph3)
# Out:
# (['order no # 123456'], ['orderno # 123456'], ['order number 123456'])

# %%
information="""
Musk in 2023
Leader of the Department of Government Efficiency
Incumbent
Assumed office
January 20, 2025
President	Donald Trump
Personal details
Born	Elon Reeve Musk
June 28, 1971 (age 53)
Pretoria, Transvaal, South Africa
Citizenship	
South Africa
Canada (from 1989)
United States (from 2002)
Political party	Republican
Spouses	
Justine Wilson
​
​(m. 2000; div. 2008)​
Talulah Riley
​
​(m. 2010; div. 2012)​
​
​(m. 2013; div. 2016)​
Children	12[1]
Parents	
Errol Musk (father)
Maye Musk (mother)
Education	University of Pennsylvania (BA, BS)
Occupation	
Founder, CEO, and chief engineer of SpaceX
CEO and product architect of Tesla, Inc.
Owner, CTO and executive chairman of X (formerly Twitter)
Founder of The Boring Company, X Corp., and xAI
Co-founder of Neuralink, OpenAI, Zip2, and X.com (part of PayPal)
President of the Musk Foundation
"""

# %%
sequence=r"age \d*"

# %%
re.findall(sequence,information)
# Out:
# ['age 53']

# %%
sequence1=r"Born(.*)\n"

# %%
re.findall(sequence1,information)
# Out:
# ['\tElon Reeve Musk']

# %%
matches=re.findall(sequence1,information)
matches[0].strip()
# Out:
# 'Elon Reeve Musk'

# %%
sequence2=r"Born.*\n(.*)\(age"
matches=re.findall(sequence2,information)
matches[0].strip()
# Out:
# 'June 28, 1971'

# %%
sequence3=r"\(age.*\n(.*)"

# %%
matches=re.findall(sequence3,information)
matches[0].strip()
# Out:
# 'Pretoria, Transvaal, South Africa'
